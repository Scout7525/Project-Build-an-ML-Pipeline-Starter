# %%
# !pip install wandb==0.16.0
# !pip install ydata-profiling==4.12.1
# !pip install pandas==2.1.3
# Out:
# Collecting wandb==0.16.0
#   Using cached wandb-0.16.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting Click!=8.0.0,>=7.1 (from wandb==0.16.0)
#   Using cached click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb==0.16.0)
#   Using cached GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/scout/miniconda3/lib/python3.12/site-packages (from wandb==0.16.0) (2.32.3)
# Requirement already satisfied: psutil>=5.0.0 in /home/scout/miniconda3/lib/python3.12/site-packages (from wandb==0.16.0) (5.9.0)
# Collecting sentry-sdk>=1.0.0 (from wandb==0.16.0)
#   Using cached sentry_sdk-2.25.1-py2.py3-none-any.whl.metadata (10 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb==0.16.0)
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting PyYAML (from wandb==0.16.0)
#   Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting setproctitle (from wandb==0.16.0)
#   Downloading setproctitle-1.3.5-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in /home/scout/miniconda3/lib/python3.12/site-packages (from wandb==0.16.0) (75.8.0)
# Collecting appdirs>=1.4.3 (from wandb==0.16.0)
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting protobuf!=4.21.0,<5,>=3.19.0 (from wandb==0.16.0)
#   Using cached protobuf-4.25.6-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: six>=1.4.0 in /home/scout/miniconda3/lib/python3.12/site-packages (from docker-pycreds>=0.4.0->wandb==0.16.0) (1.17.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb==0.16.0)
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/scout/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/scout/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/scout/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/scout/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (2025.1.31)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.16.0)
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Using cached wandb-0.16.0-py3-none-any.whl (2.1 MB)
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Using cached protobuf-4.25.6-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Using cached sentry_sdk-2.25.1-py2.py3-none-any.whl (339 kB)
# Downloading PyYAML-6.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (767 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 9.6 MB/s eta 0:00:00
# Downloading setproctitle-1.3.5-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: appdirs, smmap, setproctitle, sentry-sdk, PyYAML, protobuf, docker-pycreds, Click, gitdb, GitPython, wandb
# Successfully installed Click-8.1.8 GitPython-3.1.44 PyYAML-6.0.2 appdirs-1.4.4 docker-pycreds-0.4.0 gitdb-4.0.12 protobuf-4.25.6 sentry-sdk-2.25.1 setproctitle-1.3.5 smmap-5.0.2 wandb-0.16.0
# Collecting ydata-profiling==4.12.1
#   Downloading ydata_profiling-4.12.1-py2.py3-none-any.whl.metadata (20 kB)
# Collecting scipy<1.14,>=1.4.1 (from ydata-profiling==4.12.1)
#   Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting pandas!=1.4.0,<3,>1.1 (from ydata-profiling==4.12.1)
#   Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
# Collecting matplotlib<3.10,>=3.5 (from ydata-profiling==4.12.1)
#   Downloading matplotlib-3.9.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: pydantic>=2 in /home/scout/miniconda3/lib/python3.12/site-packages (from ydata-profiling==4.12.1) (2.10.3)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /home/scout/miniconda3/lib/python3.12/site-packages (from ydata-profiling==4.12.1) (6.0.2)
# Collecting jinja2<3.2,>=2.11.1 (from ydata-profiling==4.12.1)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting visions<0.7.7,>=0.7.5 (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1)
#   Downloading visions-0.7.6-py3-none-any.whl.metadata (11 kB)
# Collecting numpy<2.2,>=1.16.0 (from ydata-profiling==4.12.1)
#   Downloading numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Collecting htmlmin==0.1.12 (from ydata-profiling==4.12.1)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting phik<0.13,>=0.11.1 (from ydata-profiling==4.12.1)
#   Downloading phik-0.12.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.6 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /home/scout/miniconda3/lib/python3.12/site-packages (from ydata-profiling==4.12.1) (2.32.3)
# Requirement already satisfied: tqdm<5,>=4.48.2 in /home/scout/miniconda3/lib/python3.12/site-packages (from ydata-profiling==4.12.1) (4.67.1)
# Collecting seaborn<0.14,>=0.10.1 (from ydata-profiling==4.12.1)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting multimethod<2,>=1.4 (from ydata-profiling==4.12.1)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling==4.12.1)
#   Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Collecting typeguard<5,>=3 (from ydata-profiling==4.12.1)
#   Downloading typeguard-4.4.2-py3-none-any.whl.metadata (3.8 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling==4.12.1)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling==4.12.1)
#   Downloading wordcloud-1.9.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Collecting dacite>=1.8 (from ydata-profiling==4.12.1)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba<1,>=0.56.0 (from ydata-profiling==4.12.1)
#   Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting PyWavelets (from imagehash==4.3.1->ydata-profiling==4.12.1)
#   Downloading pywavelets-1.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting pillow (from imagehash==4.3.1->ydata-profiling==4.12.1)
#   Downloading pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (8.9 kB)
# Collecting MarkupSafe>=2.0 (from jinja2<3.2,>=2.11.1->ydata-profiling==4.12.1)
#   Downloading MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.0 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1)
#   Downloading contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Collecting cycler>=0.10 (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1)
#   Downloading fonttools-4.57.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (102 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1)
#   Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: packaging>=20.0 in /home/scout/miniconda3/lib/python3.12/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (24.2)
# Collecting pyparsing>=2.3.1 (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/scout/miniconda3/lib/python3.12/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (2.9.0.post0)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba<1,>=0.56.0->ydata-profiling==4.12.1)
#   Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.0 kB)
# Collecting pytz>=2020.1 (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting joblib>=0.14.1 (from phik<0.13,>=0.11.1->ydata-profiling==4.12.1)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/scout/miniconda3/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling==4.12.1) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /home/scout/miniconda3/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling==4.12.1) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/scout/miniconda3/lib/python3.12/site-packages (from pydantic>=2->ydata-profiling==4.12.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/scout/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/scout/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/scout/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/scout/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (2025.1.31)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling==4.12.1)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting attrs>=19.3.0 (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting networkx>=2.4 (from visions<0.7.7,>=0.7.5->visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: six>=1.5 in /home/scout/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.17.0)
# Downloading ydata_profiling-4.12.1-py2.py3-none-any.whl (390 kB)
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading matplotlib-3.9.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 29.1 MB/s eta 0:00:00a 0:00:01
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading numba-0.61.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 21.3 MB/s eta 0:00:00
# Downloading numpy-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 53.4 MB/s eta 0:00:00a 0:00:01
# Downloading pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 36.1 MB/s eta 0:00:00 0:00:01
# Downloading phik-0.12.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (687 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.2/687.2 kB 14.5 MB/s eta 0:00:00
# Downloading scipy-1.13.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 56.3 MB/s eta 0:00:0000:0100:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading statsmodels-0.14.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 43.2 MB/s eta 0:00:00a 0:00:01
# Downloading typeguard-4.4.2-py3-none-any.whl (35 kB)
# Downloading visions-0.7.6-py3-none-any.whl (104 kB)
# Downloading wordcloud-1.9.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (539 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 539.2/539.2 kB 9.3 MB/s eta 0:00:00
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading contourpy-1.3.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.57.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 40.0 MB/s eta 0:00:00
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading kiwisolver-1.4.8-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 27.6 MB/s eta 0:00:00
# Downloading llvmlite-0.44.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 57.8 MB/s eta 0:00:0000:0100:01
# Downloading MarkupSafe-3.0.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (23 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 27.0 MB/s eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading pillow-11.2.1-cp312-cp312-manylinux_2_28_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 37.4 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading pywavelets-1.8.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 46.3 MB/s eta 0:00:00
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py) ... done
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27129 sha256=72dcaa4b720166e80470d06d254bd963f6e1d3e8604cef2b2d2ad0322ae4a17e
#   Stored in directory: /home/scout/.cache/pip/wheels/5f/d4/d7/4189b07b5902ee9f3ce0dbb14909fbe8037c39d6c63ffd49c9
# Successfully built htmlmin
# Installing collected packages: pytz, htmlmin, tzdata, typeguard, pyparsing, pillow, numpy, networkx, multimethod, MarkupSafe, llvmlite, kiwisolver, joblib, fonttools, dacite, cycler, attrs, scipy, PyWavelets, patsy, pandas, numba, jinja2, contourpy, visions, statsmodels, matplotlib, imagehash, wordcloud, seaborn, phik, ydata-profiling
# Successfully installed MarkupSafe-3.0.2 PyWavelets-1.8.0 attrs-25.3.0 contourpy-1.3.1 cycler-0.12.1 dacite-1.9.2 fonttools-4.57.0 htmlmin-0.1.12 imagehash-4.3.1 jinja2-3.1.6 joblib-1.4.2 kiwisolver-1.4.8 llvmlite-0.44.0 matplotlib-3.9.4 multimethod-1.12 networkx-3.4.2 numba-0.61.2 numpy-2.1.3 pandas-2.2.3 patsy-1.0.1 phik-0.12.4 pillow-11.2.1 pyparsing-3.2.3 pytz-2025.2 scipy-1.13.1 seaborn-0.13.2 statsmodels-0.14.4 typeguard-4.4.2 tzdata-2025.2 visions-0.7.6 wordcloud-1.9.4 ydata-profiling-4.12.1
# Collecting pandas==2.1.3
#   Downloading pandas-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting numpy<2,>=1.26.0 (from pandas==2.1.3)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/scout/miniconda3/lib/python3.12/site-packages (from pandas==2.1.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/scout/miniconda3/lib/python3.12/site-packages (from pandas==2.1.3) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /home/scout/miniconda3/lib/python3.12/site-packages (from pandas==2.1.3) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/scout/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.1.3) (1.17.0)
# Downloading pandas-2.1.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 29.6 MB/s eta 0:00:0000:010:01
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 42.6 MB/s eta 0:00:0000:010:01
# Installing collected packages: numpy, pandas
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.3
#     Uninstalling numpy-2.1.3:
#       Successfully uninstalled numpy-2.1.3
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.3
#     Uninstalling pandas-2.2.3:
#       Successfully uninstalled pandas-2.2.3
# Successfully installed numpy-1.26.4 pandas-2.1.3

# %% [markdown]
# 1. Fetch the artifact we just created (sample.csv) from W&B and read it with pandas:

# %%
import wandb
import pandas as pd
# Note that we use save_code=True in the call to wandb.init so the notebook is uploaded and versioned by W&B
run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: scout7525 (scout7525-western-governors-university). Use `wandb login --relogin` to force relogin
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core

# %% [markdown]
# 2. Explore the data in df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20000 non-null  int64
#  1   name                            19993 non-null  object
#  2   host_id                         20000 non-null  int64
#  3   host_name                       19992 non-null  object
#  4   neighbourhood_group             20000 non-null  object
#  5   neighbourhood                   20000 non-null  object
#  6   latitude                        20000 non-null  float64
#  7   longitude                       20000 non-null  float64
#  8   room_type                       20000 non-null  object
#  9   price                           20000 non-null  int64
#  10  minimum_nights                  20000 non-null  int64
#  11  number_of_reviews               20000 non-null  int64
#  12  last_review                     15877 non-null  object
#  13  reviews_per_month               15877 non-null  float64
#  14  calculated_host_listings_count  20000 non-null  int64
#  15  availability_365                20000 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.000000e+04  2.000000e+04  20000.000000  20000.000000  20000.000000
# mean   1.892380e+07  6.746034e+07     40.728455    -73.952125    153.269050
# std    1.101223e+07  7.857936e+07      0.054755      0.046559    243.325609
# min    2.539000e+03  2.571000e+03     40.508730    -74.239140      0.000000
# 25%    9.393540e+06  7.853718e+06     40.689420    -73.983030     69.000000
# 50%    1.952117e+07  3.111431e+07     40.722730    -73.955640    105.000000
# 75%    2.912936e+07  1.068426e+08     40.762990    -73.936380    175.000000
# max    3.648561e+07  2.742733e+08     40.913060    -73.717950  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20000.000000       20000.000000       15877.000000
# mean         6.992100          23.274100           1.377446
# std         21.645449          44.927793           1.683006
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          2.000000           5.000000           0.720000
# 75%          5.000000          23.000000           2.010000
# max       1250.000000         607.000000          27.950000
#
#        calculated_host_listings_count  availability_365
# count                    20000.000000      20000.000000
# mean                         6.955450        112.901200
# std                         32.433831        131.762226
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         44.000000
# 75%                          2.000000        229.000000
# max                        327.000000        365.000000

# %%
df.head()
# Out:
#          id                                               name    host_id  \
# 0   9138664                Private Lg Room 15 min to Manhattan   47594947
# 1  31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 2   8741020  Voted #1 Location Quintessential 1BR W Village...   45854238
# 3  34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 4  23203149   Big beautiful bedroom in huge Bushwick apartment     143460
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0      Iris              Queens       Sunnyside  40.74271  -73.92493
# 1    Johlex           Manhattan  Hell's Kitchen  40.76682  -73.98878
# 2      John           Manhattan    West Village  40.73631  -74.00611
# 3     Regan              Queens         Astoria  40.76424  -73.92351
# 4     Megan            Brooklyn        Bushwick  40.69839  -73.92044
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     74               2                  6  2019-05-26
# 1  Entire home/apt    170               3                  0         NaN
# 2  Entire home/apt    245               3                 51  2018-09-19
# 3  Entire home/apt    125               3                  1  2019-05-24
# 4     Private room     65               2                  8  2019-06-23
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.13                               1                 5
# 1                NaN                               1               188
# 2               1.12                               1                 0
# 3               0.65                               1                13
# 4               0.52                               2                 8

# %% [markdown]
# 3. What do you notice in the data? Look around and see what you can find.
#
# > For example, there are missing values in a few columns and the column `last_review` is a date but it is in string format. Look also at the `price` column, and note the outliers. There are some zeros and some very high prices. After talking to your stakeholders, you decide to consider from a minimum of `$10` to a maximum of `$350` per night.

# %% [markdown]
# 4. Fix some of the little problems we have found in the data with the following code:

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %% [markdown]
# Note how we did not impute missing values. We will do that in the inference pipeline, so we will be able to handle missing values also in production.

# %% [markdown]
# 5. Check with df.info() that all obvious problems have been solved

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 2.5+ MB

# %% [markdown]
# 6. Terminate the run by running `run.finish()`

# %%
run.finish()
# Out:
# wandb: WARNING Source type is set to 'repo' but some required information is missing from the environment. A job will not be created from this run. See https://docs.wandb.ai/guides/launch/create-job
# wandb: WARNING Unable to render HTML, can't import display from ipython.core
# wandb: WARNING Unable to render HTML, can't import display from ipython.core

# %% [markdown]
# 7. Save the notebook.
